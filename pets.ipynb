# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 727kB 5.4MB/s
#      |████████████████████████████████| 1.0MB 14.6MB/s
#      |████████████████████████████████| 358kB 28.9MB/s
#      |████████████████████████████████| 51kB 9.3MB/s
#      |████████████████████████████████| 61kB 9.8MB/s
#      |████████████████████████████████| 40kB 7.1MB/s
#      |████████████████████████████████| 40kB 7.7MB/s
#      |████████████████████████████████| 92kB 11.8MB/s
#      |████████████████████████████████| 61kB 10.7MB/s
#      |████████████████████████████████| 51kB 9.6MB/s
#      |████████████████████████████████| 2.6MB 30.9MB/s
# Mounted at /content/gdrive

# %%
from fastbook import *
from fastai.vision.widgets import *
import os
os.mkdir('images_pets')

# %%
# key = os.environ.get('AZURE_SEARCH_KEY', 'ef9f4f70e65540d1b206c7e99d4e02e5')

# %%
# search_images_bing
# Out:
# <function fastbook.search_images_bing>

# %%
# results = search_images_bing(key, 'dog')
# ims = results.attrgot('content_url')
# len(ims)
# Out:
# 150

# %%
# dest = 'images_pets/dog.jpg'
# download_url(ims[0], dest)
# im = Image.open(dest)
# im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=96x128 at 0x7F5D7B0E4A90>

# %%
# pet_types = 'cat','dog'
# path = Path('pets')

# %%
# def download_image_inner_mine(dest, inp, timeout=4):
#     i,url = inp
#     suffix = re.findall(r'\.\w+?(?=(?:\?|$))', url)
#     suffix = suffix[0] if len(suffix)>0  else '.jpg'
#     try: download_url(url, dest/f"{i:08d}{suffix}", overwrite=True, show_progress=False, timeout=timeout)
#     except Exception as e: f"Couldn't download {url}."
# def download_images_mine(dest, urls):
#   dest = Path(dest)
#   dest.mkdir(exist_ok=True)
#   for i, url in enumerate(urls):
#     download_image_inner_mine( dest, [i, url], timeout=4)

# if not path.exists():
#     path.mkdir()
#     for o in pet_types:
#         dest = (path/o)
#         dest.mkdir(exist_ok=True)
#         results = search_images_bing(key, f'{o}')
#         print(f'{o}')
#         download_images_mine(dest, urls=results.attrgot('content_url'))
# Out:
# cat
# dog

# %%
# fns = get_image_files(path)
# fns
# Out:
# (#300) [Path('pets/dog/00000036.jpg'),Path('pets/dog/00000054.jpg'),Path('pets/dog/00000108.jpg'),Path('pets/dog/00000093.jpg'),Path('pets/dog/00000028.jpg'),Path('pets/dog/00000120.jpg'),Path('pets/dog/00000021.jpg'),Path('pets/dog/00000127.jpg'),Path('pets/dog/00000019.jpg'),Path('pets/dog/00000111.jpg')...]

# %%
# [fn.unlink() for fn in fns if not verify_image(fn)]
# Out:
# []

# %%
# pets = DataBlock(
#     blocks=(ImageBlock, CategoryBlock), 
#     get_items=get_image_files, 
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#     get_y=parent_label,
#     item_tfms=Resize(128))

# %%
# dls = pets.dataloaders(path)

# %%
# dls.valid.show_batch(max_n=4, nrows=1)

# %%
# pets = pets.new(item_tfms=Resize(128, ResizeMethod.Squish))
# dls = pets.dataloaders(path)
# dls.valid.show_batch(max_n=4, nrows=1)

# %%
# pets = pets.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
# dls = pets.dataloaders(path)
# dls.valid.show_batch(max_n=4, nrows=1)

# %%
# pets = pets.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
# dls = pets.dataloaders(path)
# dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
# pets = pets.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
# dls = pets.dataloaders(path)
# dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %%
# pets = pets.new(
#     item_tfms=RandomResizedCrop(224, min_scale=0.5),
#     batch_tfms=aug_transforms())
# dls = pets.dataloaders(path)

# %%
# learn = cnn_learner(dls, resnet18, metrics=error_rate)
# learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.086674</td>
#       <td>0.286253</td>
#       <td>0.133333</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.296308</td>
#       <td>0.089369</td>
#       <td>0.050000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.228626</td>
#       <td>0.020740</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.164810</td>
#       <td>0.009057</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.135173</td>
#       <td>0.004618</td>
#       <td>0.000000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# interp = ClassificationInterpretation.from_learner(learn)
# interp.plot_confusion_matrix()

# %%
# interp.plot_top_losses(5, nrows=1)

# %%
@patch
def __getitem__(self:Box, i): return self.children[i]

# Cell
def widget(im, *args, **layout):
    "Convert anything that can be `display`ed by IPython into a widget"
    o = Output(layout=merge(*args, layout))
    with o: display(im)
    return o

# Cell
def _update_children(change):
    for o in change['owner'].children:
        if not o.layout.flex: o.layout.flex = '0 0 auto'

# Cell
def carousel(children=(), **layout):
    "A horizontally scrolling carousel"
    def_layout = dict(overflow='scroll hidden', flex_flow='row', display='flex')
    res = Box([], layout=merge(def_layout, layout))
    res.observe(_update_children, names='children')
    res.children = children
    return res

# Cell
def _open_thumb(fn, h, w): return Image.open(fn).to_thumb(h, w).convert('RGBA')

def _get_iw_info(learn, ds_idx=0):
    dl = learn.dls[ds_idx].new(shuffle=False, drop_last=False)
    inp,probs,targs,preds,losses = learn.get_preds(dl=dl, with_input=True, with_loss=True, with_decoded=True)
    inp,targs = L(zip(*dl.decode_batch((inp,targs), max_n=9999)))
    return L([dl.dataset.items,targs,losses]).zip()
class ImagesCleaner:
    "A widget that displays all images in `fns` along with a `Dropdown`"
    def __init__(self, opts=(), height=128, width=256, max_n=30):
        opts = ('<Keep>', '<Delete>')+tuple(opts)
        store_attr('opts,height,width,max_n')
        self.widget = carousel(width='100%')

    def set_fns(self, fns):
        self.fns = L(fns)[:self.max_n]
        ims = [_open_thumb(fn, self.height, self.width) for fn in  self.fns]
        self.widget.children = [VBox([widget(im, height=f'{self.height}px'), Dropdown(
            options=self.opts, layout={'width': 'max-content'})]) for im in ims]

    def _ipython_display_(self): display(self.widget)
    def values(self): return L(self.widget.children).itemgot(1).attrgot('value')
    def delete(self): return self.values().argwhere(eq('<Delete>'))
    def change(self):
        idxs = self.values().argwhere(negate_func(in_(['<Delete>','<Keep>'])))
        return idxs.zipwith(self.values()[idxs])
@delegates(ImagesCleaner)
class ImageClassifierCleaner(GetAttr):
    "A widget that provides an `ImagesCleaner` with a CNN `Learner`"
    def __init__(self, learn, **kwargs):
        vocab = learn.dls.vocab
        self.default = self.iw = ImagesCleaner(vocab, **kwargs)
        self.dd_cats = Dropdown(options=vocab)
        self.dd_ds   = Dropdown(options=('Train','Valid'))
        self.iwis = _get_iw_info(learn,0),_get_iw_info(learn,1)
        self.dd_ds.observe(self.on_change_ds, 'value')
        self.dd_cats.observe(self.on_change_ds, 'value')
        self.on_change_ds()
        self.widget = VBox([self.dd_cats, self.dd_ds, self.iw.widget])

    def _ipython_display_(self): display(self.widget)
    def on_change_ds(self, change=None):
        info = L(o for o in self.iwis[self.dd_ds.index] if o[1]==self.dd_cats.value)
        self.iw.set_fns(info.sorted(2, reverse=True).itemgot(0))

# %%
# cleaner = ImageClassifierCleaner(learn)
# cleaner
# Out:
# VBox(children=(Dropdown(options=('cat', 'dog'), value='cat'), Dropdown(options=('Train', 'Valid'), value='Trai…

# %%
#hide
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
# learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images_pets/dog.jpg')
# Out:
# ('dog', tensor(1), tensor([1.4075e-06, 1.0000e+00]))

# %%
learn_inf.dls.vocab
# Out:
# (#2) ['cat','dog']

# %% [markdown]
# Creating a Notebook App from the model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images_pets/dog.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: dog; Probability: 1.0000')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your photo!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your photo!'), FileUpload(value={'IMG_7616.JPG': {'metadata': {'lastModifie…

# %%
# from google.colab import files
# files.download('export.pkl')

# %% [markdown]
# Turning the Notebook into real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable voila —sys-prefix
# Out:
# Collecting voila
#   Downloading https://files.pythonhosted.org/packages/43/b1/a4e5f6b40d6e0e5d77af0defcd4674e74bca7225b717b5d2ed1559baf35e/voila-0.2.2-py3-none-any.whl (6.9MB)
#      |████████████████████████████████| 6.9MB 4.7MB/s
# Collecting jupyter-server<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/20/22/c55b67b17586f50c27f6be58997df13a36bf6e66f7783eab7b415730b26e/jupyter_server-0.3.0-py3-none-any.whl (150kB)
#      |████████████████████████████████| 153kB 53.9MB/s
# Collecting jupyter-client<7,>=6.1.3
#   Downloading https://files.pythonhosted.org/packages/dc/41/9fa443d5ae8907dd8f7d12146cb0092dc053afd67b5b57e7e8786a328547/jupyter_client-6.1.7-py3-none-any.whl (108kB)
#      |████████████████████████████████| 112kB 56.7MB/s
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from voila) (0.5.0)
# Collecting nbconvert<7,>=6.0.0
#   Downloading https://files.pythonhosted.org/packages/da/70/5562e5505a418ac64bbf2f99810134fded2119f672636a02c8da1f760093/nbconvert-6.0.5-py3-none-any.whl (505kB)
#      |████████████████████████████████| 512kB 51.9MB/s
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (19.0.2)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (5.1.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (4.3.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (4.10.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (2.11.2)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (4.6.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from jupyter-server<0.4.0,>=0.3.0->voila) (5.0.7)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: async-generator in /usr/local/lib/python3.6/dist-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.6/dist-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (0.1.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (2.6.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (3.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.1->jupyter-server<0.4.0,>=0.3.0->voila) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2.1->jupyter-server<0.4.0,>=0.3.0->voila) (4.4.2)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (5.5.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.3->jupyter-server<0.4.0,>=0.3.0->voila) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->jupyter-server<0.4.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->jupyter-server<0.4.0,>=0.3.0->voila) (2.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (50.3.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0->ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (4.8.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->jupyter-server<0.4.0,>=0.3.0->voila) (0.2.5)
# ERROR: nbdev 1.0.18 has requirement nbconvert<6, but you'll have nbconvert 6.0.5 which is incompatible.
# Installing collected packages: jupyter-client, nbconvert, jupyter-server, voila
#   Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# Successfully installed jupyter-client-6.1.7 jupyter-server-0.3.0 nbconvert-6.0.5 voila-0.2.2
# Enabling: voila
# - Writing config: /root/.jupyter
#     - Validating...
# Error loading server extension voila
#       X is voila importable?
# Enabling: —sys-prefix
# - Writing config: /root/.jupyter
#     - Validating...
# Error loading server extension —sys-prefix
#       X is —sys-prefix importable?
